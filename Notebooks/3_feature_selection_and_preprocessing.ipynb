# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df_users = pd.read_csv("datasets/user_data.csv")

# %%
df_users
# Out:
#       count_deposit  count_borrow  count_repay  count_withdraw  \
# 0                 1             0            0               0
# 1                 1             0            0               0
# 2                 2             0            0               0
# 3                 0             0            0              17
# 4               250            15            4             130
# ...             ...           ...          ...             ...
# 3492              1             0            0               0
# 3493              4             1            0               2
# 3494              1             0            0               4
# 3495             13             2            2               5
# 3496             53            48           36              46
#
#       count_liquidation   avg_deposit    avg_borrow     avg_repay  \
# 0                     0   1987.661667      0.000000      0.000000
# 1                     0    285.694195      0.000000      0.000000
# 2                     0      0.002576      0.000000      0.000000
# 3                     0      0.000000      0.000000      0.000000
# 4                     0   3701.962773   8690.383071  17537.561563
# ...                 ...           ...           ...           ...
# 3492                  0      0.000099      0.000000      0.000000
# 3493                  0      5.660717      2.330733      0.000000
# 3494                  0  35309.730934      0.000000      0.000000
# 3495                  0    524.095419    601.108680     99.948030
# 3496                  0   9667.210627  21677.333636  21117.981660
#
#       avg_withdraw  withdraw_to_depo  borrow_to_deposit  repay_to_borrow
# 0         0.000000      0.000000e+00           0.000000         0.000000
# 1         0.000000      0.000000e+00           0.000000         0.000000
# 2         0.000000      0.000000e+00           0.000000         0.000000
# 3       115.336637      1.960723e+09           0.000000         0.000000
# 4      6338.750550      8.903791e-01           0.140850         0.538145
# ...            ...               ...                ...              ...
# 3492      0.000000      0.000000e+00           0.000000         0.000000
# 3493      8.023082      7.086631e-01           0.102935         0.000000
# 3494  17646.593608      1.999061e+00           0.000000         0.000000
# 3495    162.529952      1.192751e-01           0.176453         0.166273
# 3496  18183.400524      1.632510e+00           1.462035         0.730647
#
# [3497 rows x 12 columns]

# %% [markdown]
# #### Calculating variance inflation factor VIF

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant
import pandas as pd

X = df_users.copy()

X = X.select_dtypes(include=["number"])


X_const = add_constant(X)

# Calculating VIF for each feature
vif_data = pd.DataFrame()
vif_data["Feature"] = X_const.columns
vif_data["VIF"] = [variance_inflation_factor(X_const.values, i) for i in range(X_const.shape[1])]

print(vif_data.sort_values("VIF", ascending=False))
# Out:
#               Feature       VIF
# 2        count_borrow  5.026272
# 8           avg_repay  4.776892
# 9        avg_withdraw  4.351798
# 3         count_repay  3.791582
# 7          avg_borrow  3.645779
# 1       count_deposit  2.671546
# 6         avg_deposit  2.620462
# 11  borrow_to_deposit  1.966275
# 12    repay_to_borrow  1.767090
# 0               const  1.646410
# 10   withdraw_to_depo  1.166182
# 5   count_liquidation  1.038647
# 4      count_withdraw  1.018902

# %% [markdown]
# #### Feature Scaling

# %%
df_users.columns
# Out:
# Index(['count_deposit', 'count_borrow', 'count_repay', 'count_withdraw',
#        'count_liquidation', 'avg_deposit', 'avg_borrow', 'avg_repay',
#        'avg_withdraw', 'withdraw_to_depo', 'borrow_to_deposit',
#        'repay_to_borrow'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split
X_train, X_test = train_test_split(df_users, test_size=0.2)

# %%
X_train.head()
# Out:
#       count_deposit  count_borrow  count_repay  count_withdraw  \
# 350              32            13           10               8
# 1846              2             0            0               0
# 2492              1             1            1               1
# 1518              1             1            0               0
# 1064              0             0            0               9
#
#       count_liquidation  avg_deposit   avg_borrow    avg_repay  avg_withdraw  \
# 350                   0   307.335407   427.805256   492.880709    779.811836
# 1846                  0     0.539011     0.000000     0.000000      0.000000
# 2492                  0  7071.698232  2045.330998  2045.330998   7071.698232
# 1518                  0     0.051302     0.004989     0.000000      0.000000
# 1064                  0     0.000000     0.000000     0.000000    538.558502
#
#       withdraw_to_depo  borrow_to_deposit  repay_to_borrow
# 350       6.343330e-01           0.565493         0.886242
# 1846      0.000000e+00           0.000000         0.000000
# 2492      1.000000e+00           0.289228         1.000000
# 1518      0.000000e+00           0.097250         0.000000
# 1064      4.847027e+09           0.000000         0.000000

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
cols_to_scale = X_train.columns
X_train[cols_to_scale] = scaler.fit_transform(X_train[cols_to_scale])
X_test[cols_to_scale] = scaler.transform(X_test[cols_to_scale])

# %%
cols_to_scale
# Out:
# Index(['count_deposit', 'count_borrow', 'count_repay', 'count_withdraw',
#        'count_liquidation', 'avg_deposit', 'avg_borrow', 'avg_repay',
#        'avg_withdraw', 'withdraw_to_depo', 'borrow_to_deposit',
#        'repay_to_borrow'],
#       dtype='object')

# %%
X_train.head()
# Out:
#       count_deposit  count_borrow  count_repay  count_withdraw  \
# 350        0.077859         0.065     0.034364        0.000561
# 1846       0.004866         0.000     0.000000        0.000000
# 2492       0.002433         0.005     0.003436        0.000070
# 1518       0.002433         0.005     0.000000        0.000000
# 1064       0.000000         0.000     0.000000        0.000631
#
#       count_liquidation   avg_deposit    avg_borrow  avg_repay  avg_withdraw  \
# 350                 0.0  1.177242e-04  1.467826e-04   0.000180      0.000276
# 1846                0.0  2.064671e-07  0.000000e+00   0.000000      0.000000
# 2492                0.0  2.708800e-03  7.017656e-04   0.000748      0.002501
# 1518                0.0  1.965094e-08  1.711823e-09   0.000000      0.000000
# 1064                0.0  0.000000e+00  0.000000e+00   0.000000      0.000190
#
#       withdraw_to_depo  borrow_to_deposit  repay_to_borrow
# 350       5.356467e-11           0.386785         0.833329
# 1846      0.000000e+00           0.000000         0.000000
# 2492      8.444252e-11           0.197825         0.940295
# 1518      0.000000e+00           0.066517         0.000000
# 1064      4.092952e-01           0.000000         0.000000

# %%
X_train.describe()
# Out:
#        count_deposit  count_borrow  count_repay  count_withdraw  \
# count    2797.000000   2797.000000  2797.000000     2797.000000
# mean        0.025665      0.023999     0.011967        0.000722
# std         0.068309      0.074501     0.045187        0.019003
# min         0.000000      0.000000     0.000000        0.000000
# 25%         0.002433      0.000000     0.000000        0.000000
# 50%         0.004866      0.000000     0.000000        0.000000
# 75%         0.014599      0.010000     0.003436        0.000210
# max         1.000000      1.000000     1.000000        1.000000
#
#        count_liquidation   avg_deposit   avg_borrow    avg_repay  \
# count        2797.000000  2.797000e+03  2797.000000  2797.000000
# mean            0.002709  2.804632e-03     0.002427     0.002872
# std             0.025646  2.942736e-02     0.028184     0.036103
# min             0.000000  0.000000e+00     0.000000     0.000000
# 25%             0.000000  3.849286e-07     0.000000     0.000000
# 50%             0.000000  4.500642e-06     0.000000     0.000000
# 75%             0.000000  2.891766e-04     0.000085     0.000038
# max             1.000000  1.000000e+00     1.000000     1.000000
#
#        avg_withdraw  withdraw_to_depo  borrow_to_deposit  repay_to_borrow
# count   2797.000000      2.797000e+03        2797.000000      2797.000000
# mean       0.005016      2.747373e-02           0.153075         0.251120
# std        0.044008      1.552185e-01           0.226545         0.389140
# min        0.000000      0.000000e+00           0.000000         0.000000
# 25%        0.000000      0.000000e+00           0.000000         0.000000
# 50%        0.000000      0.000000e+00           0.000000         0.000000
# 75%        0.000315      8.350108e-11           0.273591         0.584607
# max        1.000000      1.000000e+00           1.000000         1.000000

# %%
X_train = X_train.reset_index()
X_test = X_test.reset_index()

# %%
X_train.describe()
# Out:
#              index  count_deposit  count_borrow  count_repay  count_withdraw  \
# count  2797.000000    2797.000000   2797.000000  2797.000000     2797.000000
# mean   1750.987487       0.025665      0.023999     0.011967        0.000722
# std    1010.456904       0.068309      0.074501     0.045187        0.019003
# min       0.000000       0.000000      0.000000     0.000000        0.000000
# 25%     881.000000       0.002433      0.000000     0.000000        0.000000
# 50%    1741.000000       0.004866      0.000000     0.000000        0.000000
# 75%    2635.000000       0.014599      0.010000     0.003436        0.000210
# max    3496.000000       1.000000      1.000000     1.000000        1.000000
#
#        count_liquidation   avg_deposit   avg_borrow    avg_repay  \
# count        2797.000000  2.797000e+03  2797.000000  2797.000000
# mean            0.002709  2.804632e-03     0.002427     0.002872
# std             0.025646  2.942736e-02     0.028184     0.036103
# min             0.000000  0.000000e+00     0.000000     0.000000
# 25%             0.000000  3.849286e-07     0.000000     0.000000
# 50%             0.000000  4.500642e-06     0.000000     0.000000
# 75%             0.000000  2.891766e-04     0.000085     0.000038
# max             1.000000  1.000000e+00     1.000000     1.000000
#
#        avg_withdraw  withdraw_to_depo  borrow_to_deposit  repay_to_borrow
# count   2797.000000      2.797000e+03        2797.000000      2797.000000
# mean       0.005016      2.747373e-02           0.153075         0.251120
# std        0.044008      1.552185e-01           0.226545         0.389140
# min        0.000000      0.000000e+00           0.000000         0.000000
# 25%        0.000000      0.000000e+00           0.000000         0.000000
# 50%        0.000000      0.000000e+00           0.000000         0.000000
# 75%        0.000315      8.350108e-11           0.273591         0.584607
# max        1.000000      1.000000e+00           1.000000         1.000000

# %%
X_train.to_csv("datasets\\train_data.csv", index=False)
X_test.to_csv("datasets\\test_data.csv", index=False)

# %%
cols_to_scale = cols_to_scale.to_list()

# %%
# from joblib import dump
# scaler_dict = {
#     "scaler":scaler,
#     "columns":cols_to_scale
# }

# %%
# dump(scaler_dict, "artifacts/scaler.joblib")
